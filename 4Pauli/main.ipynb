# %%
import os, time
import numpy as np
import matplotlib.pyplot as plt

from lib.sample import Sample
from lib.rnn import RNN
from lib.estimation import Estimation


os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
if __name__ == "__main__" :
    work = [0, 1, 1]
    N = 2
    Ns = 100
    POVM = "4Pauli"
    train_steps = 50
    batch_size = 32
    
    cont = False
    
    if work[0] == 1 :
        sam = Sample(N =N)
        sam.sample(Ns=Ns, POVM=POVM)
    
        
    if work[1] == 1 :
        if batch_size > Ns :
            batch_size = Ns
            
        rnn = RNN(N=N, POVM=POVM, train_steps=train_steps, batch_size=batch_size, G=1, gru=50)
        rnn.train()
    
    if work[2] == 1 :
        est = Estimation(N=N, POVM=POVM, Re=cont)
        cf, qf = est.fidelity(qf=True, mle=cont)
# Out:
# WARNING:tensorflow:From /home/wenjie_jiang/Project/rnn_tomography/4Pauli/lib/rnn.py:78: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/wenjie_jiang/Project/rnn_tomography/4Pauli/lib/rnn.py:54: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/wenjie_jiang/Project/rnn_tomography/4Pauli/lib/rnn.py:54: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# ...
